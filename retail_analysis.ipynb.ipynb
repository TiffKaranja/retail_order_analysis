# %% [markdown]
# ##### retrieving kaggle credentials securely using dotenv function

# %%
# %pip install kaggle
# Out:
# Requirement already satisfied: kaggle in c:\users\tiff\appdata\local\programs\python\python313\lib\site-packages (1.7.4.5)
# Requirement already satisfied: bleach in c:\users\tiff\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\tiff\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (2025.4.26)
# Requirement already satisfied: charset-normalizer in c:\users\tiff\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (3.4.2)
# Requirement already satisfied: idna in c:\users\tiff\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (3.10)
# Requirement already satisfied: protobuf in c:\users\tiff\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (6.31.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\tiff\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in c:\users\tiff\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in c:\users\tiff\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: setuptools>=21.0.0 in c:\users\tiff\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (80.7.1)
# Requirement already satisfied: six>=1.10 in c:\users\tiff\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode in c:\users\tiff\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in c:\users\tiff\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\tiff\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (2.4.0)
# Requirement already satisfied: webencodings in c:\users\tiff\appdata\local\programs\python\python313\lib\site-packages (from kaggle) (0.5.1)
# Requirement already satisfied: colorama in c:\users\tiff\appdata\local\programs\python\python313\lib\site-packages (from tqdm->kaggle) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pandas as pd 
# %pip install numpy as np
# Out:
# Requirement already satisfied: pandas in c:\users\tiff\appdata\local\programs\python\python313\lib\site-packages (2.2.3)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement as (from versions: none)
# ERROR: No matching distribution found for as
# Requirement already satisfied: numpy in c:\users\tiff\appdata\local\programs\python\python313\lib\site-packages (2.2.6)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement as (from versions: none)
# ERROR: No matching distribution found for as

# %%
### retrieving kaggle credentials securely using dotenv function

import os
from dotenv import load_dotenv
load_dotenv()

## secure credentials
KAGGLE_USERNAME = os.getenv ("KAGGLE_USERNAME")
KAGGLE_KEY = os.getenv ("KAGGLE_KEY")

# %%
##import pandas as libraries
import pandas as pd

# %%
import kaggle

# %%
import kaggle
from kaggle.api.kaggle_api_extended  import KaggleApi

# %%
api = KaggleApi()
api.authenticate
# Out:
# <bound method KaggleApi.authenticate of <kaggle.api.kaggle_api_extended.KaggleApi object at 0x00000226F8E58550>>

# %%
# !kaggle datasets download -d ankitbansal06/retail-orders
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# retail-orders.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
##loading the data set into python using read_csv function

df=pd.read_csv(r'C:\Users\TIFF\Documents\postgresql_project\orders.csv')
df.head(30)
# Out:
#     Order Id  Order Date       Ship Mode      Segment        Country  \
# 0          1  2023-03-01    Second Class     Consumer  United States
# 1          2  2023-08-15    Second Class     Consumer  United States
# 2          3  2023-01-10    Second Class    Corporate  United States
# 3          4  2022-06-18  Standard Class     Consumer  United States
# 4          5  2022-07-13  Standard Class     Consumer  United States
# 5          6  2022-03-13   Not Available     Consumer  United States
# 6          7  2022-12-28  Standard Class     Consumer  United States
# 7          8  2022-01-25  Standard Class     Consumer  United States
# 8          9  2023-03-23   Not Available     Consumer  United States
# 9         10  2023-05-16  Standard Class     Consumer  United States
# 10        11  2023-03-31   Not Available     Consumer  United States
# 11        12  2023-12-25   Not Available     Consumer  United States
# 12        13  2022-02-11  Standard Class     Consumer  United States
# 13        14  2023-07-18  Standard Class     Consumer  United States
# 14        15  2023-11-09         unknown  Home Office  United States
# 15        16  2022-06-18  Standard Class  Home Office  United States
# 16        17  2022-02-04  Standard Class     Consumer  United States
# 17        18  2023-08-04    Second Class     Consumer  United States
# 18        19  2022-01-23    Second Class     Consumer  United States
# 19        20  2022-01-11    Second Class     Consumer  United States
# 20        21  2022-10-05    Second Class     Consumer  United States
# 21        22  2023-07-16  Standard Class    Corporate  United States
# 22        23  2023-05-06  Standard Class    Corporate  United States
# 23        24  2023-05-21    Second Class     Consumer  United States
# 24        25  2023-02-24  Standard Class     Consumer  United States
# 25        26  2022-06-20    Second Class     Consumer  United States
# 26        27  2022-02-08    Second Class     Consumer  United States
# 27        28  2023-12-11  Standard Class     Consumer  United States
# 28        29  2022-08-21  Standard Class     Consumer  United States
# 29        30  2022-08-14  Standard Class     Consumer  United States
#
#                City           State  Postal Code   Region         Category  \
# 0         Henderson        Kentucky        42420    South        Furniture
# 1         Henderson        Kentucky        42420    South        Furniture
# 2       Los Angeles      California        90036     West  Office Supplies
# 3   Fort Lauderdale         Florida        33311    South        Furniture
# 4   Fort Lauderdale         Florida        33311    South  Office Supplies
# 5       Los Angeles      California        90032     West        Furniture
# 6       Los Angeles      California        90032     West  Office Supplies
# 7       Los Angeles      California        90032     West       Technology
# 8       Los Angeles      California        90032     West  Office Supplies
# 9       Los Angeles      California        90032     West  Office Supplies
# 10      Los Angeles      California        90032     West        Furniture
# 11      Los Angeles      California        90032     West       Technology
# 12          Concord  North Carolina        28027    South  Office Supplies
# 13          Seattle      Washington        98103     West  Office Supplies
# 14       Fort Worth           Texas        76106  Central  Office Supplies
# 15       Fort Worth           Texas        76106  Central  Office Supplies
# 16          Madison       Wisconsin        53711  Central  Office Supplies
# 17      West Jordan            Utah        84084     West  Office Supplies
# 18    San Francisco      California        94109     West  Office Supplies
# 19    San Francisco      California        94109     West       Technology
# 20    San Francisco      California        94109     West  Office Supplies
# 21          Fremont        Nebraska        68025  Central  Office Supplies
# 22          Fremont        Nebraska        68025  Central  Office Supplies
# 23     Philadelphia    Pennsylvania        19140     East        Furniture
# 24             Orem            Utah        84057     West        Furniture
# 25      Los Angeles      California        90049     West  Office Supplies
# 26      Los Angeles      California        90049     West       Technology
# 27     Philadelphia    Pennsylvania        19140     East        Furniture
# 28     Philadelphia    Pennsylvania        19140     East  Office Supplies
# 29     Philadelphia    Pennsylvania        19140     East        Furniture
#
#    Sub Category       Product Id  cost price  List Price  Quantity  \
# 0     Bookcases  FUR-BO-10001798         240         260         2
# 1        Chairs  FUR-CH-10000454         600         730         3
# 2        Labels  OFF-LA-10000240          10          10         2
# 3        Tables  FUR-TA-10000577         780         960         5
# 4       Storage  OFF-ST-10000760          20          20         2
# 5   Furnishings  FUR-FU-10001487          50          50         7
# 6           Art  OFF-AR-10002833          10          10         4
# 7        Phones  TEC-PH-10002275         860         910         6
# 8       Binders  OFF-BI-10003910          20          20         3
# 9    Appliances  OFF-AP-10002892          90         110         5
# 10       Tables  FUR-TA-10001539        1470        1710         9
# 11       Phones  TEC-PH-10002033         750         910         4
# 12        Paper  OFF-PA-10002365          20          20         3
# 13      Binders  OFF-BI-10003656         360         410         3
# 14   Appliances  OFF-AP-10002311          60          70         5
# 15      Binders  OFF-BI-10000756           0           0         3
# 16      Storage  OFF-ST-10004186         610         670         6
# 17      Storage  OFF-ST-10000107          60          60         2
# 18          Art  OFF-AR-10003056          10          10         2
# 19       Phones  TEC-PH-10001949         170         210         3
# 20      Binders  OFF-BI-10002215          20          20         4
# 21          Art  OFF-AR-10000246          20          20         7
# 22   Appliances  OFF-AP-10001492          50          60         7
# 23       Chairs  FUR-CH-10002774          60          70         2
# 24       Tables  FUR-TA-10000577         900        1040         3
# 25      Binders  OFF-BI-10001634          10          10         2
# 26  Accessories  TEC-AC-10003027          80          90         3
# 27    Bookcases  FUR-BO-10004834        2740        3080         7
# 28      Binders  OFF-BI-10000474          10          10         2
# 29  Furnishings  FUR-FU-10004848         100         120         3
#
#     Discount Percent
# 0                  2
# 1                  3
# 2                  5
# 3                  2
# 4                  5
# 5                  3
# 6                  3
# 7                  5
# 8                  2
# 9                  3
# 10                 3
# 11                 3
# 12                 3
# 13                 2
# 14                 5
# 15                 5
# 16                 3
# 17                 4
# 18                 4
# 19                 3
# 20                 2
# 21                 4
# 22                 3
# 23                 4
# 24                 5
# 25                 5
# 26                 3
# 27                 3
# 28                 5
# 29                 4

# %%
### checking data frame shape 
##data frames is basically columns and rows

df.shape
print(df.shape)
# Out:
# (9994, 16)

# %%
###count of missing values per column 
df.isnull() .sum()
# Out:
# Order Id            0
# Order Date          0
# Ship Mode           1
# Segment             0
# Country             0
# City                0
# State               0
# Postal Code         0
# Region              0
# Category            0
# Sub Category        0
# Product Id          0
# cost price          0
# List Price          0
# Quantity            0
# Discount Percent    0
# dtype: int64

# %%
### summary

df.info
# Out:
# <bound method DataFrame.info of       Order Id  Order Date       Ship Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# 1           Henderson    Kentucky        42420  South        Furniture
# 2         Los Angeles  California        90036   West  Office Supplies
# 3     Fort Lauderdale     Florida        33311  South        Furniture
# 4     Fort Lauderdale     Florida        33311  South  Office Supplies
# ...               ...         ...          ...    ...              ...
# 9989            Miami     Florida        33180  South        Furniture
# 9990       Costa Mesa  California        92627   West        Furniture
# 9991       Costa Mesa  California        92627   West       Technology
# 9992       Costa Mesa  California        92627   West  Office Supplies
# 9993      Westminster  California        92683   West  Office Supplies
#
#      Sub Category       Product Id  cost price  List Price  Quantity  \
# 0       Bookcases  FUR-BO-10001798         240         260         2
# 1          Chairs  FUR-CH-10000454         600         730         3
# 2          Labels  OFF-LA-10000240          10          10         2
# 3          Tables  FUR-TA-10000577         780         960         5
# 4         Storage  OFF-ST-10000760          20          20         2
# ...           ...              ...         ...         ...       ...
# 9989  Furnishings  FUR-FU-10001889          30          30         3
# 9990  Furnishings  FUR-FU-10000747          70          90         2
# 9991       Phones  TEC-PH-10003645         220         260         2
# 9992        Paper  OFF-PA-10004041          30          30         4
# 9993   Appliances  OFF-AP-10002684         210         240         2
#
#       Discount Percent
# 0                    2
# 1                    3
# 2                    5
# 3                    2
# 4                    5
# ...                ...
# 9989                 4
# 9990                 4
# 9991                 2
# 9992                 3
# 9993                 3
#
# [9994 rows x 16 columns]>

# %%
### loop that prints the 
### for is used in a loop

names= ["Alice", "Bob","Charlie"]
print(names[0])
# Out:
# Alice

# %%
### loop that prints the unique values for each object-type column exclude or
###object type refers to a string 

for column in df.select_dtypes(include=['object']).columns:
    if column != 'Order Date':
        print(f"\n{column} unique values:")
        print(df[column].unique())
# Out:
# Ship Mode unique values:
# ['Second Class' 'Standard Class' 'Not Available' 'unknown' 'First Class'
#  nan 'Same Day']
#
# Segment unique values:
# ['Consumer' 'Corporate' 'Home Office']
#
# Country unique values:
# ['United States']
#
# City unique values:
# ['Henderson' 'Los Angeles' 'Fort Lauderdale' 'Concord' 'Seattle'
#  'Fort Worth' 'Madison' 'West Jordan' 'San Francisco' 'Fremont'
#  'Philadelphia' 'Orem' 'Houston' 'Richardson' 'Naperville' 'Melbourne'
#  'Eagan' 'Westland' 'Dover' 'New Albany' 'New York City' 'Troy' 'Chicago'
#  'Gilbert' 'Springfield' 'Jackson' 'Memphis' 'Decatur' 'Durham' 'Columbia'
#  'Rochester' 'Minneapolis' 'Portland' 'Saint Paul' 'Aurora' 'Charlotte'
#  'Orland Park' 'Urbandale' 'Columbus' 'Bristol' 'Wilmington' 'Bloomington'
#  'Phoenix' 'Roseville' 'Independence' 'Pasadena' 'Newark' 'Franklin'
#  'Scottsdale' 'San Jose' 'Edmond' 'Carlsbad' 'San Antonio' 'Monroe'
#  'Fairfield' 'Grand Prairie' 'Redlands' 'Hamilton' 'Westfield' 'Akron'
#  'Denver' 'Dallas' 'Whittier' 'Saginaw' 'Medina' 'Dublin' 'Detroit'
#  'Tampa' 'Santa Clara' 'Lakeville' 'San Diego' 'Brentwood' 'Chapel Hill'
#  'Morristown' 'Cincinnati' 'Inglewood' 'Tamarac' 'Colorado Springs'
#  'Belleville' 'Taylor' 'Lakewood' 'Arlington' 'Arvada' 'Hackensack'
#  'Saint Petersburg' 'Long Beach' 'Hesperia' 'Murfreesboro' 'Layton'
#  'Austin' 'Lowell' 'Manchester' 'Harlingen' 'Tucson' 'Quincy'
#  'Pembroke Pines' 'Des Moines' 'Peoria' 'Las Vegas' 'Warwick' 'Miami'
#  'Huntington Beach' 'Richmond' 'Louisville' 'Lawrence' 'Canton'
#  'New Rochelle' 'Gastonia' 'Jacksonville' 'Auburn' 'Norman' 'Park Ridge'
#  'Amarillo' 'Lindenhurst' 'Huntsville' 'Fayetteville' 'Costa Mesa'
#  'Parker' 'Atlanta' 'Gladstone' 'Great Falls' 'Lakeland' 'Montgomery'
#  'Mesa' 'Green Bay' 'Anaheim' 'Marysville' 'Salem' 'Laredo' 'Grove City'
#  'Dearborn' 'Warner Robins' 'Vallejo' 'Mission Viejo' 'Rochester Hills'
#  'Plainfield' 'Sierra Vista' 'Vancouver' 'Cleveland' 'Tyler' 'Burlington'
#  'Waynesboro' 'Chester' 'Cary' 'Palm Coast' 'Mount Vernon' 'Hialeah'
#  'Oceanside' 'Evanston' 'Trenton' 'Cottage Grove' 'Bossier City'
#  'Lancaster' 'Asheville' 'Lake Elsinore' 'Omaha' 'Edmonds' 'Santa Ana'
#  'Milwaukee' 'Florence' 'Lorain' 'Linden' 'Salinas' 'New Brunswick'
#  'Garland' 'Norwich' 'Alexandria' 'Toledo' 'Farmington' 'Riverside'
#  'Torrance' 'Round Rock' 'Boca Raton' 'Virginia Beach' 'Murrieta'
#  'Olympia' 'Washington' 'Jefferson City' 'Saint Peters' 'Rockford'
#  'Brownsville' 'Yonkers' 'Oakland' 'Clinton' 'Encinitas' 'Roswell'
#  'Jonesboro' 'Antioch' 'Homestead' 'La Porte' 'Lansing' 'Cuyahoga Falls'
#  'Reno' 'Harrisonburg' 'Escondido' 'Royal Oak' 'Rockville' 'Coral Springs'
#  'Buffalo' 'Boynton Beach' 'Gulfport' 'Fresno' 'Greenville' 'Macon'
#  'Cedar Rapids' 'Providence' 'Pueblo' 'Deltona' 'Murray' 'Middletown'
#  'Freeport' 'Pico Rivera' 'Provo' 'Pleasant Grove' 'Smyrna' 'Parma'
#  'Mobile' 'New Bedford' 'Irving' 'Vineland' 'Glendale' 'Niagara Falls'
#  'Thomasville' 'Westminster' 'Coppell' 'Pomona' 'North Las Vegas'
#  'Allentown' 'Tempe' 'Laguna Niguel' 'Bridgeton' 'Everett' 'Watertown'
#  'Appleton' 'Bellevue' 'Allen' 'El Paso' 'Grapevine' 'Carrollton' 'Kent'
#  'Lafayette' 'Tigard' 'Skokie' 'Plano' 'Suffolk' 'Indianapolis' 'Bayonne'
#  'Greensboro' 'Baltimore' 'Kenosha' 'Olathe' 'Tulsa' 'Redmond' 'Raleigh'
#  'Muskogee' 'Meriden' 'Bowling Green' 'South Bend' 'Spokane' 'Keller'
#  'Port Orange' 'Medford' 'Charlottesville' 'Missoula' 'Apopka' 'Reading'
#  'Broomfield' 'Paterson' 'Oklahoma City' 'Chesapeake' 'Lubbock'
#  'Johnson City' 'San Bernardino' 'Leominster' 'Bozeman' 'Perth Amboy'
#  'Ontario' 'Rancho Cucamonga' 'Moorhead' 'Mesquite' 'Stockton'
#  'Ormond Beach' 'Sunnyvale' 'York' 'College Station' 'Saint Louis'
#  'Manteca' 'San Angelo' 'Salt Lake City' 'Knoxville' 'Little Rock'
#  'Lincoln Park' 'Marion' 'Littleton' 'Bangor' 'Southaven' 'New Castle'
#  'Midland' 'Sioux Falls' 'Fort Collins' 'Clarksville' 'Sacramento'
#  'Thousand Oaks' 'Malden' 'Holyoke' 'Albuquerque' 'Sparks' 'Coachella'
#  'Elmhurst' 'Passaic' 'North Charleston' 'Newport News' 'Jamestown'
#  'Mishawaka' 'La Quinta' 'Tallahassee' 'Nashville' 'Bellingham'
#  'Woodstock' 'Haltom City' 'Wheeling' 'Summerville' 'Hot Springs'
#  'Englewood' 'Las Cruces' 'Hoover' 'Frisco' 'Vacaville' 'Waukesha'
#  'Bakersfield' 'Pompano Beach' 'Corpus Christi' 'Redondo Beach' 'Orlando'
#  'Orange' 'Lake Charles' 'Highland Park' 'Hempstead' 'Noblesville'
#  'Apple Valley' 'Mount Pleasant' 'Sterling Heights' 'Eau Claire' 'Pharr'
#  'Billings' 'Gresham' 'Chattanooga' 'Meridian' 'Bolingbrook' 'Maple Grove'
#  'Woodland' 'Missouri City' 'Pearland' 'San Mateo' 'Grand Rapids'
#  'Visalia' 'Overland Park' 'Temecula' 'Yucaipa' 'Revere' 'Conroe'
#  'Tinley Park' 'Dubuque' 'Dearborn Heights' 'Santa Fe' 'Hickory'
#  'Carol Stream' 'Saint Cloud' 'North Miami' 'Plantation'
#  'Port Saint Lucie' 'Rock Hill' 'Odessa' 'West Allis' 'Chula Vista'
#  'Manhattan' 'Altoona' 'Thornton' 'Champaign' 'Texarkana' 'Edinburg'
#  'Baytown' 'Greenwood' 'Woonsocket' 'Superior' 'Bedford' 'Covington'
#  'Broken Arrow' 'Miramar' 'Hollywood' 'Deer Park' 'Wichita' 'Mcallen'
#  'Iowa City' 'Boise' 'Cranston' 'Port Arthur' 'Citrus Heights'
#  'The Colony' 'Daytona Beach' 'Bullhead City' 'Portage' 'Fargo' 'Elkhart'
#  'San Gabriel' 'Margate' 'Sandy Springs' 'Mentor' 'Lawton' 'Hampton'
#  'Rome' 'La Crosse' 'Lewiston' 'Hattiesburg' 'Danville' 'Logan'
#  'Waterbury' 'Athens' 'Avondale' 'Marietta' 'Yuma' 'Wausau' 'Pasco'
#  'Oak Park' 'Pensacola' 'League City' 'Gaithersburg' 'Lehi' 'Tuscaloosa'
#  'Moreno Valley' 'Georgetown' 'Loveland' 'Chandler' 'Helena' 'Kirkwood'
#  'Waco' 'Frankfort' 'Bethlehem' 'Grand Island' 'Woodbury' 'Rogers'
#  'Clovis' 'Jupiter' 'Santa Barbara' 'Cedar Hill' 'Norfolk' 'Draper'
#  'Ann Arbor' 'La Mesa' 'Pocatello' 'Holland' 'Milford' 'Buffalo Grove'
#  'Lake Forest' 'Redding' 'Chico' 'Utica' 'Conway' 'Cheyenne' 'Owensboro'
#  'Caldwell' 'Kenner' 'Nashua' 'Bartlett' 'Redwood City' 'Lebanon'
#  'Santa Maria' 'Des Plaines' 'Longview' 'Hendersonville' 'Waterloo'
#  'Cambridge' 'Palatine' 'Beverly' 'Eugene' 'Oxnard' 'Renton' 'Glenview'
#  'Delray Beach' 'Commerce City' 'Texas City' 'Wilson' 'Rio Rancho'
#  'Goldsboro' 'Montebello' 'El Cajon' 'Beaumont' 'West Palm Beach'
#  'Abilene' 'Normal' 'Saint Charles' 'Camarillo' 'Hillsboro' 'Burbank'
#  'Modesto' 'Garden City' 'Atlantic City' 'Longmont' 'Davis' 'Morgan Hill'
#  'Clifton' 'Sheboygan' 'East Point' 'Rapid City' 'Andover' 'Kissimmee'
#  'Shelton' 'Danbury' 'Sanford' 'San Marcos' 'Greeley' 'Mansfield' 'Elyria'
#  'Twin Falls' 'Coral Gables' 'Romeoville' 'Marlborough' 'Laurel' 'Bryan'
#  'Pine Bluff' 'Aberdeen' 'Hagerstown' 'East Orange' 'Arlington Heights'
#  'Oswego' 'Coon Rapids' 'San Clemente' 'San Luis Obispo' 'Springdale'
#  'Lodi' 'Mason']
#
# State unique values:
# ['Kentucky' 'California' 'Florida' 'North Carolina' 'Washington' 'Texas'
#  'Wisconsin' 'Utah' 'Nebraska' 'Pennsylvania' 'Illinois' 'Minnesota'
#  'Michigan' 'Delaware' 'Indiana' 'New York' 'Arizona' 'Virginia'
#  'Tennessee' 'Alabama' 'South Carolina' 'Oregon' 'Colorado' 'Iowa' 'Ohio'
#  'Missouri' 'Oklahoma' 'New Mexico' 'Louisiana' 'Connecticut' 'New Jersey'
#  'Massachusetts' 'Georgia' 'Nevada' 'Rhode Island' 'Mississippi'
#  'Arkansas' 'Montana' 'New Hampshire' 'Maryland' 'District of Columbia'
#  'Kansas' 'Vermont' 'Maine' 'South Dakota' 'Idaho' 'North Dakota'
#  'Wyoming' 'West Virginia']
#
# Region unique values:
# ['South' 'West' 'Central' 'East']
#
# Category unique values:
# ['Furniture' 'Office Supplies' 'Technology']
#
# Sub Category unique values:
# ['Bookcases' 'Chairs' 'Labels' 'Tables' 'Storage' 'Furnishings' 'Art'
#  'Phones' 'Binders' 'Appliances' 'Paper' 'Accessories' 'Envelopes'
#  'Fasteners' 'Supplies' 'Machines' 'Copiers']
#
# Product Id unique values:
# ['FUR-BO-10001798' 'FUR-CH-10000454' 'OFF-LA-10000240' ...
#  'OFF-AP-10003099' 'TEC-PH-10002645' 'OFF-ST-10001627']

# %%
df.columns
print(df.columns)
# Out:
# Index(['Order Id', 'Order Date', 'Ship Mode', 'Segment', 'Country', 'City',
#        'State', 'Postal Code', 'Region', 'Category', 'Sub Category',
#        'Product Id', 'cost price', 'List Price', 'Quantity',
#        'Discount Percent'],
#       dtype='object')

# %%
import numpy as np

# %%
### replace the entries 'Not Available' and 'unknown' in the Ship Mode column with NaN

values_to_replace =['Not Available','Unknown']
df['Ship Mode'] = df['Ship Mode'].replace(values_to_replace,np.nan)
df
# Out:
#       Order Id  Order Date       Ship Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# 1           Henderson    Kentucky        42420  South        Furniture
# 2         Los Angeles  California        90036   West  Office Supplies
# 3     Fort Lauderdale     Florida        33311  South        Furniture
# 4     Fort Lauderdale     Florida        33311  South  Office Supplies
# ...               ...         ...          ...    ...              ...
# 9989            Miami     Florida        33180  South        Furniture
# 9990       Costa Mesa  California        92627   West        Furniture
# 9991       Costa Mesa  California        92627   West       Technology
# 9992       Costa Mesa  California        92627   West  Office Supplies
# 9993      Westminster  California        92683   West  Office Supplies
#
#      Sub Category       Product Id  cost price  List Price  Quantity  \
# 0       Bookcases  FUR-BO-10001798         240         260         2
# 1          Chairs  FUR-CH-10000454         600         730         3
# 2          Labels  OFF-LA-10000240          10          10         2
# 3          Tables  FUR-TA-10000577         780         960         5
# 4         Storage  OFF-ST-10000760          20          20         2
# ...           ...              ...         ...         ...       ...
# 9989  Furnishings  FUR-FU-10001889          30          30         3
# 9990  Furnishings  FUR-FU-10000747          70          90         2
# 9991       Phones  TEC-PH-10003645         220         260         2
# 9992        Paper  OFF-PA-10004041          30          30         4
# 9993   Appliances  OFF-AP-10002684         210         240         2
#
#       Discount Percent
# 0                    2
# 1                    3
# 2                    5
# 3                    2
# 4                    5
# ...                ...
# 9989                 4
# 9990                 4
# 9991                 2
# 9992                 3
# 9993                 3
#
# [9994 rows x 16 columns]

# %%
### rename all DataFrame columns by lowercasing and replacing spaces with underscores.

df.columns = df.columns.str.lower().str.replace(' ','_')
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# 1           Henderson    Kentucky        42420  South        Furniture
# 2         Los Angeles  California        90036   West  Office Supplies
# 3     Fort Lauderdale     Florida        33311  South        Furniture
# 4     Fort Lauderdale     Florida        33311  South  Office Supplies
# ...               ...         ...          ...    ...              ...
# 9989            Miami     Florida        33180  South        Furniture
# 9990       Costa Mesa  California        92627   West        Furniture
# 9991       Costa Mesa  California        92627   West       Technology
# 9992       Costa Mesa  California        92627   West  Office Supplies
# 9993      Westminster  California        92683   West  Office Supplies
#
#      sub_category       product_id  cost_price  list_price  quantity  \
# 0       Bookcases  FUR-BO-10001798         240         260         2
# 1          Chairs  FUR-CH-10000454         600         730         3
# 2          Labels  OFF-LA-10000240          10          10         2
# 3          Tables  FUR-TA-10000577         780         960         5
# 4         Storage  OFF-ST-10000760          20          20         2
# ...           ...              ...         ...         ...       ...
# 9989  Furnishings  FUR-FU-10001889          30          30         3
# 9990  Furnishings  FUR-FU-10000747          70          90         2
# 9991       Phones  TEC-PH-10003645         220         260         2
# 9992        Paper  OFF-PA-10004041          30          30         4
# 9993   Appliances  OFF-AP-10002684         210         240         2
#
#       discount_percent
# 0                    2
# 1                    3
# 2                    5
# 3                    2
# 4                    5
# ...                ...
# 9989                 4
# 9990                 4
# 9991                 2
# 9992                 3
# 9993                 3
#
# [9994 rows x 16 columns]

# %%
### Compute a discount column as list_price * discount_percent / 100.

df['discount'] = df['list_price'] * df['discount_percent']/100
print(df['discount'])
# Out:
# 0        5.2
# 1       21.9
# 2        0.5
# 3       19.2
# 4        1.0
#         ...
# 9989     1.2
# 9990     3.6
# 9991     5.2
# 9992     0.9
# 9993     7.2
# Name: discount, Length: 9994, dtype: float64

# %%
### Compute a selling_price column as list_price - discount.

df['selling_price']=df['list_price'] - df['discount']

# %%
### Compute a profit column as selling_price - cost_price
df['profit']=df['selling_price'] - df['cost_price']

# %%
### Drop Unneeded Columns: Remove cost_price, list_price, and discount_percent from the DataFrame.

columns_to_drop=['list_price','discount_percent', 'cost_price']

df=df.drop(columns_to_drop,axis=1)
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# 1           Henderson    Kentucky        42420  South        Furniture
# 2         Los Angeles  California        90036   West  Office Supplies
# 3     Fort Lauderdale     Florida        33311  South        Furniture
# 4     Fort Lauderdale     Florida        33311  South  Office Supplies
# ...               ...         ...          ...    ...              ...
# 9989            Miami     Florida        33180  South        Furniture
# 9990       Costa Mesa  California        92627   West        Furniture
# 9991       Costa Mesa  California        92627   West       Technology
# 9992       Costa Mesa  California        92627   West  Office Supplies
# 9993      Westminster  California        92683   West  Office Supplies
#
#      sub_category       product_id  quantity  discount  selling_price  profit
# 0       Bookcases  FUR-BO-10001798         2       5.2          254.8    14.8
# 1          Chairs  FUR-CH-10000454         3      21.9          708.1   108.1
# 2          Labels  OFF-LA-10000240         2       0.5            9.5    -0.5
# 3          Tables  FUR-TA-10000577         5      19.2          940.8   160.8
# 4         Storage  OFF-ST-10000760         2       1.0           19.0    -1.0
# ...           ...              ...       ...       ...            ...     ...
# 9989  Furnishings  FUR-FU-10001889         3       1.2           28.8    -1.2
# 9990  Furnishings  FUR-FU-10000747         2       3.6           86.4    16.4
# 9991       Phones  TEC-PH-10003645         2       5.2          254.8    34.8
# 9992        Paper  OFF-PA-10004041         4       0.9           29.1    -0.9
# 9993   Appliances  OFF-AP-10002684         2       7.2          232.8    22.8
#
# [9994 rows x 16 columns]

# %%
### Datetime Conversion: Convert the order_date column to pandas datetime with ISO8601 format.

df['order_date']=pd.to_datetime(df['order_date'],format='ISO8601')
df['order_date']
# Out:
# 0      2023-03-01
# 1      2023-08-15
# 2      2023-01-10
# 3      2022-06-18
# 4      2022-07-13
#           ...
# 9989   2023-02-18
# 9990   2023-03-17
# 9991   2022-08-07
# 9992   2022-11-19
# 9993   2022-07-17
# Name: order_date, Length: 9994, dtype: datetime64[ns]

# %% [markdown]
# ### Database Creation and Schema Definition

# %%
### Create Database (SQL Script):
#### Write a pure SQL file (create_database.sql) that creates a new MySQL database named retail_db if it does not exist, and grants all privileges to the specified user.

# %%
import psycopg2

# %%
conn = psycopg2.connect(
        database="retail_db",
        user="postgres",
        password="newpassword",
        host="127.0.0.1",
        port="5432"
)

# %%
cur = conn.cursor()

# %%
cur.execute("""CREATE TABLE datacamp_courses(
            course_id SERIAL PRIMARY KEY,
            course_name VARCHAR (50) UNIQUE NOT NULL,
            course_instructor VARCHAR (100) NOT NULL,
            topic VARCHAR (20) NOT NULL);
            """)
# Out:
# ---------------------------------------------------------------------------
# DuplicateTable                            Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 cur.execute("""CREATE TABLE datacamp_courses(
#       2             course_id SERIAL PRIMARY KEY,
#       3             course_name VARCHAR (50) UNIQUE NOT NULL,
#       4             course_instructor VARCHAR (100) NOT NULL,
#       5             topic VARCHAR (20) NOT NULL);
#       6             """)
#
# DuplicateTable: relation "datacamp_courses" already exists

# %%
# Make the changes to the database persistent
conn.commit()
# Close cursor and communication with the database
cur.close()
conn.close()

# %%
from sqlalchemy import create_engine, MetaData, Table

import os
from dotenv import load_dotenv

load_dotenv()

engine = create_engine(
    f"postgresql+psycopg2://{os.getenv('USER')}:{os.getenv('PASSWORD')}@{os.getenv('HOST')}:{os.getenv('PORT')}/{os.getenv('DATABASE')}"
)

# %%
# Reflect existing tables
metadata = MetaData()
metadata.reflect(bind=engine)

# Drop the 'orders' table if it exists
if 'orders' in metadata.tables:
    orders_table = metadata.tables['orders']
    orders_table.drop(engine)
    print("Dropped 'orders' table successfully.")
else:
    print("'orders' table does not exist.")
# Out:
# 'orders' table does not exist.

# %%
### Creating the orders table using the SQL in your schema.sql file

from sqlalchemy import text

# Read the schema.sql file
file_path = r'C:\Users\TIFF\Documents\postgresql_project\schema.sql'
with open(file_path, 'r') as file:
    sql_commands = file.read()

# Execute the SQL to create tables
with engine.connect() as connection:
    connection.execute(text(sql_commands))
    connection.commit()
    print("orders table created successfully.")
# Out:
# orders table created successfully.

# %%
import pandas as pd

csv_path = r'C:\Users\TIFF\Documents\postgresql_project\orders.csv'

# Load the data into a DataFrame
df = pd.read_csv(csv_path)

# %%
### reviewing the data frame
print(df.head())
print(df.columns)
# Out:
#    order_id order_date       ship_mode    segment        country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  quantity  discount  selling_price  profit
# 0    Bookcases  FUR-BO-10001798         2       5.2          254.8    14.8
# 1       Chairs  FUR-CH-10000454         3      21.9          708.1   108.1
# 2       Labels  OFF-LA-10000240         2       0.5            9.5    -0.5
# 3       Tables  FUR-TA-10000577         5      19.2          940.8   160.8
# 4      Storage  OFF-ST-10000760         2       1.0           19.0    -1.0
# Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category', 'sub_category',
#        'product_id', 'quantity', 'discount', 'selling_price', 'profit'],
#       dtype='object')

# %%
from sqlalchemy import create_engine
from dotenv import load_dotenv
import os

# Load .env file
load_dotenv()

# Recreate engine
engine = create_engine(
    f"postgresql+psycopg2://{os.getenv('USER')}:{os.getenv('PASSWORD')}@{os.getenv('HOST')}:{os.getenv('PORT')}/{os.getenv('DATABASE')}"
)

# %%
# Load CSV
csv_path = r'C:\Users\TIFF\Documents\postgresql_project\orders.csv'
df = pd.read_csv(csv_path)

# Rename columns to match table schema
df.columns = [
    'order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
    'state', 'postal_code', 'region', 'category', 'sub_category', 'product_id',
    'cost_price', 'list_price', 'quantity', 'discount_percent'
]

# Write to SQL
df.to_sql(
    name='orders',
    con=engine,
    if_exists='append',
    index=False
)

print("✅ Data inserted into 'orders' table successfully.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 15
#       6 df.columns = [
#       7     'order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#       8     'state', 'postal_code', 'region', 'category', 'sub_category', 'product_id',
#       9     'cost_price', 'list_price', 'quantity', 'discount_percent'
#      10 ]
#      12 # Write to SQL
#      13 df.to_sql(
#      14     name='orders',
# ---> 15     con=engine,
#      16     if_exists='append',
#      17     index=False
#      18 )
#      20 print("✅ Data inserted into 'orders' table successfully.")
#
# NameError: name 'engine' is not defined

# %%
from sqlalchemy import MetaData

metadata = MetaData()
metadata.reflect(bind=engine)

if 'orders' in metadata.tables:
    orders_table = metadata.tables['orders']
    orders_table.drop(engine)
    print("Dropped 'orders' table successfully.")
else:
    print("'orders' table does not exist.")
# Out:
# Dropped 'orders' table successfully.

# %%
from sqlalchemy import text

file_path = r'C:\Users\TIFF\Documents\postgresql_project\schema.sql'
with open(file_path, 'r') as file:
    sql_commands = file.read()

with engine.connect() as connection:
    connection.execute(text(sql_commands))
    connection.commit()
    print("orders table created successfully.")
# Out:
# orders table created successfully.

# %%
with engine.connect() as conn:
    result = conn.execute(text("SELECT column_name, data_type FROM information_schema.columns WHERE table_name='orders';"))
    for row in result:
        print(row)
# Out:
# ('order_id', 'integer')
# ('order_date', 'date')
# ('postal_code', 'integer')
# ('cost_price', 'numeric')
# ('list_price', 'numeric')
# ('quantity', 'integer')
# ('discount_percent', 'numeric')
# ('product_id', 'text')
# ('region', 'text')
# ('category', 'text')
# ('sub_category', 'text')
# ('ship_mode', 'text')
# ('segment', 'text')
# ('country', 'text')
# ('city', 'text')
# ('state', 'text')

# %%
df.rename(columns={
    'discount': 'discount_percent',}, inplace=True)

# %%
df.to_sql(
    name='orders',
    con=engine,
    if_exists='append',  # Append data to existing table
    index=False          # Don't write DataFrame index as a column
)
print("Data inserted into 'orders' table successfully.")
# Out:
# Data inserted into 'orders' table successfully.

# %%
### verifying all back rows
from sqlalchemy import text

with engine.connect() as conn:
    result = conn.execute(text("SELECT * FROM orders LIMIT 5;"))
    rows = result.fetchall()
    for row in rows:
        print(row)
# Out:
# (1, datetime.date(2023, 3, 1), 'Second Class', 'Consumer', 'United States', 'Henderson', 'Kentucky', 42420, 'South', 'Furniture', 'Bookcases', 'FUR-BO-10001798', Decimal('240'), Decimal('260'), 2, Decimal('2'))
# (2, datetime.date(2023, 8, 15), 'Second Class', 'Consumer', 'United States', 'Henderson', 'Kentucky', 42420, 'South', 'Furniture', 'Chairs', 'FUR-CH-10000454', Decimal('600'), Decimal('730'), 3, Decimal('3'))
# (3, datetime.date(2023, 1, 10), 'Second Class', 'Corporate', 'United States', 'Los Angeles', 'California', 90036, 'West', 'Office Supplies', 'Labels', 'OFF-LA-10000240', Decimal('10'), Decimal('10'), 2, Decimal('5'))
# (4, datetime.date(2022, 6, 18), 'Standard Class', 'Consumer', 'United States', 'Fort Lauderdale', 'Florida', 33311, 'South', 'Furniture', 'Tables', 'FUR-TA-10000577', Decimal('780'), Decimal('960'), 5, Decimal('2'))
# (5, datetime.date(2022, 7, 13), 'Standard Class', 'Consumer', 'United States', 'Fort Lauderdale', 'Florida', 33311, 'South', 'Office Supplies', 'Storage', 'OFF-ST-10000760', Decimal('20'), Decimal('20'), 2, Decimal('5'))

# %%
### Read All Rows: Write a SQLAlchemy  query to select all rows from orders, execute it, and fetch all results.
from sqlalchemy import text

with engine.connect() as connection:
    result = connection.execute(text("SELECT * FROM orders;"))
    all_orders = result.fetchall()

# Print the first 5 rows to check
for row in all_orders[:5]:
    print(row)
# Out:
# (1, datetime.date(2023, 3, 1), 'Second Class', 'Consumer', 'United States', 'Henderson', 'Kentucky', 42420, 'South', 'Furniture', 'Bookcases', 'FUR-BO-10001798', Decimal('240'), Decimal('260'), 2, Decimal('2'))
# (2, datetime.date(2023, 8, 15), 'Second Class', 'Consumer', 'United States', 'Henderson', 'Kentucky', 42420, 'South', 'Furniture', 'Chairs', 'FUR-CH-10000454', Decimal('600'), Decimal('730'), 3, Decimal('3'))
# (3, datetime.date(2023, 1, 10), 'Second Class', 'Corporate', 'United States', 'Los Angeles', 'California', 90036, 'West', 'Office Supplies', 'Labels', 'OFF-LA-10000240', Decimal('10'), Decimal('10'), 2, Decimal('5'))
# (4, datetime.date(2022, 6, 18), 'Standard Class', 'Consumer', 'United States', 'Fort Lauderdale', 'Florida', 33311, 'South', 'Furniture', 'Tables', 'FUR-TA-10000577', Decimal('780'), Decimal('960'), 5, Decimal('2'))
# (5, datetime.date(2022, 7, 13), 'Standard Class', 'Consumer', 'United States', 'Fort Lauderdale', 'Florida', 33311, 'South', 'Office Supplies', 'Storage', 'OFF-ST-10000760', Decimal('20'), Decimal('20'), 2, Decimal('5'))

# %%
### Total Revenue per Category-Sum list_price grouped by category, ordered descending.
revenue_per_category = (df.groupby('category')['selling_price'].sum().sort_values(ascending=False).reset_index())
print(revenue_per_category)
# Out:
#           category  selling_price
# 0       Technology       806873.5
# 1        Furniture       715340.7
# 2  Office Supplies       693644.5

# %%
## 6.2 Top 3 profitable cities

Top_3_cities = (df.groupby('city')['profit'].sum().sort_values(ascending= False).reset_index())
Top_3_cities.head(3)
# Out:
#             city   profit
# 0  New York City  20925.7
# 1    Los Angeles  15088.4
# 2  San Francisco  10140.1

# %%
## 6.3 Compute Profit Margin per product

profit_margin_per_product = (df.groupby('product_id')['profit'].sum() / df.groupby('product_id')['selling_price'].sum()).reset_index()
profit_margin_per_product.columns = ['product_id', 'profit_margin']
print(profit_margin_per_product)
# Out:
#            product_id  profit_margin
# 0     FUR-BO-10000112       0.056018
# 1     FUR-BO-10000330       0.141258
# 2     FUR-BO-10000362       0.090648
# 3     FUR-BO-10000468       0.121937
# 4     FUR-BO-10000711       0.049224
# ...               ...            ...
# 1857  TEC-PH-10004912       0.108951
# 1858  TEC-PH-10004922       0.055240
# 1859  TEC-PH-10004924      -0.037344
# 1860  TEC-PH-10004959       0.087591
# 1861  TEC-PH-10004977       0.078251
#
# [1862 rows x 2 columns]

# %%
## 6.4 Order count by ship mode in descending format

order_count_by_ship_mode = (df.groupby('ship_mode')['order_id'].count().sort_values(ascending=False).reset_index())
order_count_by_ship_mode.columns = ['ship_mode', 'order_count'] 
print(order_count_by_ship_mode)
# Out:
#         ship_mode  order_count
# 0  Standard Class         5962
# 1    Second Class         1945
# 2     First Class         1538
# 3        Same Day          543
# 4         unknown            1

# %%
## 6.5 Finding the month with the highest orders

df['order_month'] = df['order_date'].dt.to_period('M')
highest_orders_month = (df.groupby('order_month')['order_id'].count().sort_values(ascending=False).reset_index())   
highest_orders_month.columns = ['order_month', 'order_count']
print(highest_orders_month.head(1))
# Out:
#   order_month  order_count
# 0     2023-07          477

# %%
## 6.6 Top 5 most discounted products

top_5_discounted_products = (df.groupby('product_id')['discount'].mean().sort_values(ascending=False).reset_index())
top_5_discounted_products.columns = ['product_id', 'average_discount']
print(top_5_discounted_products.head(5))
# Out:
#         product_id  average_discount
# 0  TEC-MA-10002412        905.600000
# 1  TEC-CO-10004722        417.200000
# 2  TEC-MA-10001047        266.500000
# 3  OFF-SU-10000151        234.733333
# 4  TEC-MA-10003979        178.500000

# %%
## 6.7 Finding the Top 3 cities by sales

top_3_cities_by_sales = (df.groupby('city')['selling_price'].sum().sort_values(ascending=False).reset_index())
top_3_cities_by_sales.columns = ['city', 'total_sales']
print(top_3_cities_by_sales.head(3))
# Out:
#             city  total_sales
# 0  New York City     247205.7
# 1    Los Angeles     169758.4
# 2        Seattle     115358.7

# %%
## 6.8 Finding average profit for 2023

df['order_year'] = df['order_date'].dt.year
average_profit_2023 = df[df['order_year'] == 2023]['profit'].mean() 
print(f"Average profit for 2023: {average_profit_2023:.2f}")
# Out:
# Average profit for 2023: 20.89

# %%
## 6.9 Showing the top five sales by sub-category

top_5_sales_by_sub_category = (df.groupby('sub_category')['selling_price'].sum().sort_values(ascending=False).reset_index())
top_5_sales_by_sub_category.columns = ['sub_category', 'total_sales']
print(top_5_sales_by_sub_category.head(5))
# Out:
#   sub_category  total_sales
# 0       Phones     318008.3
# 1       Chairs     316825.1
# 2      Storage     215908.0
# 3       Tables     199361.2
# 4      Binders     196038.6

# %%
## 6.10 Finding the average selling price per category

average_selling_price_per_category = (df.groupby('category')['selling_price'].mean().reset_index())
average_selling_price_per_category.columns = ['category', 'average_selling_price']
print(average_selling_price_per_category)
# Out:
#           category  average_selling_price
# 0        Furniture             337.265771
# 1  Office Supplies             115.108613
# 2       Technology             436.856253

# %%
## 6.11 Top 10 products by order count

top_10_products_by_order_count = (df.groupby('product_id')['order_id'].count().sort_values(ascending=False).reset_index())
top_10_products_by_order_count.columns = ['product_id', 'order_count']
print(top_10_products_by_order_count.head(10))
# Out:
#         product_id  order_count
# 0  OFF-PA-10001970           19
# 1  TEC-AC-10003832           18
# 2  FUR-FU-10004270           16
# 3  FUR-CH-10001146           15
# 4  TEC-AC-10003628           15
# 5  FUR-CH-10002647           15
# 6  TEC-AC-10002049           15
# 7  FUR-CH-10002880           14
# 8  FUR-CH-10003774           14
# 9  OFF-PA-10002377           14

# %%
## 6.12 Top 5 prfitable products

top_5_profitable_products = (df.groupby('product_id')['profit'].sum().sort_values(ascending=False).reset_index())
top_5_profitable_products.columns = ['product_id', 'total_profit']
print(top_5_profitable_products.head(5))
# Out:
#         product_id  total_profit
# 0  TEC-CO-10004722        5644.0
# 1  TEC-MA-10002412        3624.4
# 2  OFF-BI-10003527        3435.3
# 3  TEC-CO-10001449        2631.2
# 4  FUR-CH-10002024        2246.2

# %%
## 6.13 Year with the highest sales 

yearly_sales = (df.groupby('order_year')['selling_price'].sum().sort_values(ascending=False).reset_index())
yearly_sales.columns = ['order_year', 'total_sales']
highest_sales_year = yearly_sales.head(1)
print(f"Year with the highest sales: {highest_sales_year['order_year'].values[0]} with sales of {highest_sales_year['total_sales'].values[0]:.2f}")
# Out:
# Year with the highest sales: 2023 with sales of 1120268.50

# %%
## 6.14 Region with lowest average discount

region_lowest_avg_discount = (df.groupby('region')['discount'].mean().sort_values().reset_index())
region_lowest_avg_discount.columns = ['region', 'average_discount']
lowest_avg_discount_region = region_lowest_avg_discount.head(1)
print(f"Region with the lowest average discount: {lowest_avg_discount_region['region'].values[0]} with an average discount of {lowest_avg_discount_region['average_discount'].values[0]:.2f}")
# Out:
# Region with the lowest average discount: Central with an average discount of 7.49

# %%
## 6.15 Yearly sales Growth

yearly_sales_growth = (df.groupby('order_year')['selling_price'].sum().pct_change().reset_index())
yearly_sales_growth.columns = ['order_year', 'sales_growth']
print(yearly_sales_growth)
# Out:
#    order_year  sales_growth
# 0        2022           NaN
# 1        2023      0.022525

# %%
## 6.16 Profit contribution by category

profit_contribution_by_category = (df.groupby('category')['profit'].sum() / df['profit'].sum()).reset_index()
profit_contribution_by_category.columns = ['category', 'profit_contribution']
print(profit_contribution_by_category)
# Out:
#           category  profit_contribution
# 0        Furniture             0.324029
# 1  Office Supplies             0.303431
# 2       Technology             0.372540

# %%
## 6.17 Find the most common ship mode

most_common_ship_mode = df['ship_mode'].mode()[0]
print(f"The most common ship mode is: {most_common_ship_mode}")
# Out:
# The most common ship mode is: Standard Class

# %%
## 6.18 Find the highest average order value by region

highest_avg_order_value_by_region = (df.groupby('region')['selling_price'].mean().sort_values(ascending=False).reset_index())
highest_avg_order_value_by_region.columns = ['region', 'average_order_value']
print(highest_avg_order_value_by_region.head(1))
# Out:
#   region  average_order_value
# 0  South           233.340432

# %%
## 6.19 Find Sales for Category & Sub category

sales_by_category_subcategory = (df.groupby(['category', 'sub_category'])['selling_price'].sum().reset_index())
sales_by_category_subcategory.columns = ['category', 'sub_category', 'total_sales']
print(sales_by_category_subcategory)
# Out:
#            category sub_category  total_sales
# 0         Furniture    Bookcases     110816.1
# 1         Furniture       Chairs     316825.1
# 2         Furniture  Furnishings      88338.3
# 3         Furniture       Tables     199361.2
# 4   Office Supplies   Appliances     103697.7
# 5   Office Supplies          Art      26259.8
# 6   Office Supplies      Binders     196038.6
# 7   Office Supplies    Envelopes      15917.2
# 8   Office Supplies    Fasteners       2938.9
# 9   Office Supplies       Labels      11994.9
# 10  Office Supplies        Paper      75831.3
# 11  Office Supplies      Storage     215908.0
# 12  Office Supplies     Supplies      45058.1
# 13       Technology  Accessories     161604.6
# 14       Technology      Copiers     144358.9
# 15       Technology     Machines     182901.7
# 16       Technology       Phones     318008.3

# %%
## 6.20 Top 3 Profitable Products per Sub-Category

profitable_products_subcategory = (df.groupby(['product_id','sub_category'])['profit'].sum().sort_values(ascending=False).reset_index())
profitable_products_subcategory.head(3)
# Out:
#         product_id sub_category  profit
# 0  TEC-CO-10004722      Copiers  5644.0
# 1  TEC-MA-10002412     Machines  3624.4
# 2  OFF-BI-10003527      Binders  3435.3

# %%
## 6.21 Monthly Order Counts for 2023

monthly_order_counts_2023 = (df[df['order_year'] == 2023].groupby(df['order_date'].dt.to_period('M'))['order_id'].count().reset_index())
monthly_order_counts_2023.columns = ['order_month', 'order_count']
print(monthly_order_counts_2023)
# Out:
#    order_month  order_count
# 0      2023-01          419
# 1      2023-02          401
# 2      2023-03          434
# 3      2023-04          400
# 4      2023-05          401
# 5      2023-06          375
# 6      2023-07          477
# 7      2023-08          420
# 8      2023-09          353
# 9      2023-10          418
# 10     2023-11          413
# 11     2023-12          446

# %%
## 6.22 states with the lowest total selling price

lowest_selling_price_states = (df.groupby('state')['selling_price'].sum().sort_values().reset_index())
lowest_selling_price_states.columns = ['state', 'total_selling_price']  
print(lowest_selling_price_states.head(5))
# Out:
#            state  total_selling_price
# 0   North Dakota                877.7
# 1  West Virginia               1170.6
# 2          Maine               1239.9
# 3   South Dakota               1276.8
# 4        Wyoming               1536.0

# %%
## 6.24 Average discount by sub category 

average_discount_by_subcategory = (df.groupby('sub_category')['discount'].mean().reset_index())
average_discount_by_subcategory.columns = ['sub_category', 'average_discount']
print(average_discount_by_subcategory)
# Out:
#    sub_category  average_discount
# 0   Accessories          7.619871
# 1    Appliances          7.944850
# 2           Art          1.130905
# 3       Binders          4.577413
# 4     Bookcases         17.341667
# 5        Chairs         18.484441
# 6       Copiers         76.045588
# 7     Envelopes          2.255118
# 8     Fasteners          0.465899
# 9   Furnishings          3.345559
# 10       Labels          1.167857
# 11     Machines         55.289565
# 12        Paper          2.057445
# 13       Phones         13.398988
# 14      Storage          9.115839
# 15     Supplies          9.115263
# 16       Tables         23.475862

# %% [markdown]
# ### Visualization

# %%
## importing data libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.head()
# Out:
#    order_id order_date       ship_mode    segment        country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  quantity  discount  selling_price  profit
# 0    Bookcases  FUR-BO-10001798         2       5.2          254.8    14.8
# 1       Chairs  FUR-CH-10000454         3      21.9          708.1   108.1
# 2       Labels  OFF-LA-10000240         2       0.5            9.5    -0.5
# 3       Tables  FUR-TA-10000577         5      19.2          940.8   160.8
# 4      Storage  OFF-ST-10000760         2       1.0           19.0    -1.0

# %%
## number of columns and rows
df.shape
# Out:
# (9994, 16)

# %% [markdown]
# #### Bar plot
# #### dispalys numerical values of categorical data to compare categories

# %%
print(df.columns)
# Out:
# Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category', 'sub_category',
#        'product_id', 'quantity', 'discount', 'selling_price', 'profit'],
#       dtype='object')

# %%
## how many orders per segment
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='category', order=df['category'].value_counts().index)
plt.title('Number of Orders per Category')
plt.xlabel('Category')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Count Plot
#
# ##### Displays counts of observations in categorical data
#
# ##### Shows the relationship between two categorical variables

# %%
#how many orders per shipping mode
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='ship_mode', order=df['ship_mode'].value_counts().index)
plt.title('Number of Orders per Shipping Mode')
plt.xlabel('Shipping Mode')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Pie Chart
#
# #### Each sector in the circle corresponds to a category of the categorical data

# %%
## order distribution by state
plt.figure(figsize=(12, 8))
df['region'].value_counts().plot.pie(autopct= '%1.2f%%', startangle=90)
plt.title('Order Distribution by region')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### Violin Plot
#
# #### Displays same overall stats of the data, including the distribution shape

# %%
## violin plot for profit by category
plt.figure(figsize=(12, 6))
sns.violinplot(data=df, x='category', y='profit', inner='quartile')
plt.title('Profit Distribution by Category')
plt.xlabel('Category')
plt.ylabel('Profit')
plt.xticks(rotation=45)
plt.show()

# %%
## violin plot for quantity based on segment (categorical vs numerical)
plt.figure(figsize=(12, 6))
sns.violinplot(data=df, x='segment', y='quantity', inner='quartile')
plt.title('Selling Price Distribution by Category')
plt.xlabel('segment')
plt.ylabel('quantity')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Stacked Bar Plot
#
# ##### segment vs ship mode (categorical vs categorical)

# %%
## stacked bar plot for order count by ship mode and category
order_count_by_ship_mode_category = df.groupby(['ship_mode', 'category']).size().unstack().fillna(0)
order_count_by_ship_mode_category.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('Order Count by Shipping Mode and Category')
plt.xlabel('Shipping Mode')
plt.ylabel('Order Count')
plt.xticks(rotation=45)
plt.legend(title='Category')
plt.show()

# %% [markdown]
# ### box plot

# %%
## box plot for discount by ship mode
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='ship_mode', y='discount')
plt.title('Discount Distribution by Shipping Mode')
plt.xlabel('Shipping Mode')
plt.ylabel('Discount')
plt.xticks(rotation=45)
plt.show()
